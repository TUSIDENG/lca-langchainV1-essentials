# %% [markdown]
# How to select model when training?

# %%
from model_select_util import ModelSelectUtil

# %%
selector = ModelSelectUtil()
selector.display_widgets()
# Out:
# ...
# Selected Platform: OpenAI
# Selected Model: gpt-4o
# Model Params for Agent: openai:gpt-4o

# %%
# 假设用户已通过 widget 选择了模型
platform = selector.get_selected_platform()
model = selector.get_selected_model()
model_param = selector.get_model_params()


print(f"Selected Platform: {platform}")
print(f"Selected Model: {model}")
print(f"Model Params for Agent: {model_param}")
# Out:
# Selected Platform: OpenAI
# Selected Model: gpt-5-nano
# Model Params for Agent: openai:gpt-5-nano
